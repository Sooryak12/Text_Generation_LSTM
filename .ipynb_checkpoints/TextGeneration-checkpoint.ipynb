# %% [markdown]
# <a href="https://colab.research.google.com/github/lmoroney/dlaicourse/blob/master/TensorFlow%20In%20Practice/Course%203%20-%20NLP/Course%203%20-%20Week%204%20-%20Lesson%202%20-%20Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf
import seaborn as sns
import numpy as np

# %%
from google.colab import files
uploadeddata=files.upload()
# Out:
#      <input type="file" id="files-f5107c12-3555-4321-af2f-de8e19379ded" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5107c12-3555-4321-af2f-de8e19379ded">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving result.txt to result (2).txt

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
tokenizer = Tokenizer()
with open('result.txt', 'rb') as f:
  message = f.read()

# %%
data=message.decode("latin1")

# %%
  
corpus=data.lower().split("\n\n")


tokenizer.fit_on_texts(corpus)
vocab_length = len(tokenizer.word_index) + 1

print(tokenizer.word_index)
# Out:
# {'the': 1, 'to': 2, 'a': 3, 'and': 4, 'in': 5, 'of': 6, 'for': 7, 'he': 8, 'i': 9, 'on': 10, 'is': 11, 'but': 12, 'was': 13, 'that': 14, 'with': 15, 'it': 16, 'at': 17, 'have': 18, 'his': 19, 'has': 20, 'be': 21, 'said': 22, 'we': 23, 'will': 24, 'as': 25, 'not': 26, 'from': 27, 'after': 28, 'had': 29, 'by': 30, 'been': 31, 'are': 32, 'they': 33, 'an': 34, 'out': 35, 'this': 36, 'their': 37, 'who': 38, 'first': 39, 'game': 40, 'against': 41, 'year': 42, 'up': 43, 'time': 44, 'when': 45, 'win': 46, 'all': 47, 'would': 48, 'england': 49, 'two': 50, 'over': 51, 'if': 52, 'last': 53, 'world': 54, '6': 55, 'one': 56, 'back': 57, 'there': 58, 'you': 59, 'also': 60, 'were': 61, 'my': 62, 'she': 63, 'can': 64, 'players': 65, 'before': 66, 'her': 67, 'team': 68, 'play': 69, "it's": 70, 'cup': 71, 'new': 72, 'him': 73, 'just': 74, 'second': 75, 'match': 76, 'half': 77, 'very': 78, 'final': 79, 'so': 80, 'six': 81, 'good': 82, 'now': 83, 'side': 84, 'which': 85, 'three': 86, 'set': 87, 'wales':
# ...

# %%
print(vocab_length)
# Out:
# 11292

# %%
seq= []
for sequence in corpus:
    converted = tokenizer.texts_to_sequences([sequence])[0]
    for i in range(1, len(converted)):
        n_gram = converted[:i+1]
        seq.append(n_gram)

# %%
print(seq[5])
# Out:
# [261, 3498, 2447]

# %%
max_len = max([len(x) for x in seq])
print(max_len)
# Out:
# 560

# %%
seq = np.array(pad_sequences(converted, maxlen=max_len, padding='pre'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\.conda\envs\tf\lib\site-packages\keras_preprocessing\sequence.py in pad_sequences(sequences, maxlen, dtype, padding, truncating, value)
#      60         try:
# ---> 61             lengths.append(len(x))
#      62         except TypeError:
#
# TypeError: object of type 'int' has no len()
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-a645a14691b9> in <module>
# ----> 1 seq = np.array(pad_sequences(converted, maxlen=max_len, padding='pre'))
#
# ~\.conda\envs\tf\lib\site-packages\keras_preprocessing\sequence.py in pad_sequences(sequences, maxlen, dtype, padding, truncating, value)
#      62         except TypeError:
#      63             raise ValueError('`sequences` must be a list of iterables. '
# ...

# %%
print(seq[5])

# %%
data = input_sequences[:,:-1],
labels=input_sequences[:,-1]

# %%
print(data[10])
print(labels[10])

# %%
labelsoft= tf.keras.utils.to_categorical(labels, num_classes=vocab_len)
print(labelsoft)

# %%
embeddings_index = dict()
f = open('glove.6B.100d.txt',encoding='utf8')

# %%
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

# %%
embedding_matrix = np.zeros((vocab_len, 100))
for word, index in tokenizer.word_index.items():
    if index > MAX_VOCAB_SIZE - 1:
        break
    else:
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[index] = embedding_vector

# %%
embedd

# %%
import tensorflow as tf

from tensorflow.keras.layers import  Bidirectional,Embedding, LSTM, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam


from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential()
model.add(Embedding(vocab_length, 100, input_length=maxlen-1))
model.add(Bidirectional(LSTM(150)))
model.add(Dense(vocab_length, activation='softmax'))
adam = Adam(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto')
r = model.fit(data, labelsoft, epochs=100, verbose=1,batch_size=128)
print(model)
# Out:
# Epoch 1/20
# 1318/1318 [==============================] - 405s 307ms/step - loss: 6.5977 - accuracy: 0.0935
# Epoch 2/20
# 1318/1318 [==============================] - 406s 308ms/step - loss: 5.4558 - accuracy: 0.1556
# Epoch 3/20
# 1318/1318 [==============================] - 407s 308ms/step - loss: 4.7971 - accuracy: 0.1917
# Epoch 4/20
# 1318/1318 [==============================] - 406s 308ms/step - loss: 4.2863 - accuracy: 0.2215
# Epoch 5/20
# 1081/1318 [=======================>......] - ETA: 1:13 - loss: 3.8616 - accuracy: 0.2577
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c0c7de2e7e2d> in <module>()
#       6 model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
#       7 earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto')
# ...

# %%
plt.plot(r.history["accuracy"],label="accuracy")
plt.plot(r.history["val_accuracy"],label="val_accuracy")
plt.legend()
